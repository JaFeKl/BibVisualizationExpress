# %%
import sys
import os

# Get the parent directory path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Add the parent directory to the Python path
sys.path.append(parent_dir)

from BibVisualizationExpress.BibVisualizationExpress import BibVisualizationExpress
bibvis = BibVisualizationExpress()

# Search and pre-processing
bibvis.search_scopus("TITLE-ABS-KEY(travel AND time AND model AND as/rs)", True)
# Out:
# /home/jfk/BibVisualizationExpress/BibVisualizationExpress/wikipedia-iso-country-codes.csv
# Retrieved 150 initial results after 0.014148399990517646 seconds
# Removed records with empty DOI: Removed 20 records, current number of records: 130
# Removed record types ['Conference Review']: Removed 0 records, current number of records: 130
#                     eid                            doi                pii  \
# 0    2-s2.0-85185402647      10.1016/j.cie.2024.109979  S0360835224001001
# 1    2-s2.0-85130024733       10.1108/JFM-11-2021-0145               None
# 2    2-s2.0-85160079572              10.1063/5.0143069               None
# 3    2-s2.0-85178245429     10.3389/fncel.2023.1267687               None
# 4    2-s2.0-85165269041    10.1109/ACCESS.2023.3296783               None
# ..                  ...                            ...                ...
# 144   2-s2.0-0028385943  10.1080/02533839.1994.9677583               None
# 146   2-s2.0-0026853218   10.1016/0377-2217(92)90234-Z   037722179290234Z
# 147   2-s2.0-0025838439      10.1080/00207549108930046               None
# 148  2-s2.0-84885992709      10.1080/00207549008942833               None
# 149   2-s2.0-0024106499      10.1080/00207548808947987               None
#
#     pubmed_id                                              title subtype  \
# 0        None  Multi-objective simulation-optimization for in...      ar
# 1        None  AS/R system travel time in class-based storage...      ar
# 2        None    Flexible manufacturing system with industry 4.0      cp
# 3        None  Activity-dependent ectopic action potentials i...      ar
# 4        None  Deep Reinforcement Learning-Based Charging Pri...      ar
# ..        ...                                                ...     ...
# 144      None  Travel time estimation for the order picking p...      ar
# 146      None  Storage layout of AS/RS racks based on recurre...      ar
# 147      None  Framework for dynamic positioning of storage/r...      ar
# 148      None  Travel-time models considering the operating c...      ar
# 149      None  A study on multi-aisle system served by a sing...      ar
#
#     subtypeDescription            creator  \
# 0              Article         Rizqi Z.U.
# 1              Article        Hoshimov A.
# 2     Conference Paper         Padhi S.N.
# 3              Article         Zhang Y.Z.
# 4              Article              Li B.
# ..                 ...                ...
# 144            Article          Chiang F.
# 146            Article  van Oudheusden D.
# 147            Article        Egbelu P.J.
# 148            Article           Hwang H.
# 149            Article           Hwang H.
#
#                                       afid  \
# 0                                 60027709
# 1                        60112930;60012162
# 2    60108710;60079446;123748398;111745109
# 3               60023653;60011460;60009796
# 4               60030835;60021666;60000937
# ..                                     ...
# 144                               60018029
# 146                               60010105
# 147                               60147936
# 148                               60032144
# 149                               60032144
#
#                                              affilname  ...    pageRange  \
# 0    National Taiwan University of Science and Tech...  ...         None
# 1    Turin Polytechnic University in Tashkent;Polit...  ...      108-123
# 2    Vignan Institute of Information Technology;K L...  ...         None
# 3    National Institute of Dental and Craniofacial ...  ...         None
# 4    University of Alberta;Nanjing University of Ae...  ...  75508-75521
# ..                                                 ...  ...          ...
# 144                      National Tsing Hua University  ...      205-211
# 146             Asian Institute of Technology Thailand  ...        48-56
# 147                  Penn State College of Engineering  ...        17-37
# 148  Korea Advanced Institute of Science and Techno...  ...    1779-1789
# 149  Korea Advanced Institute of Science and Techno...  ...    1727-1737
#
#                                            description  \
# 0    An Automated Storage and Retrieval System (AS/...
# 1    Purpose: This paper aims to propose a simulati...
# 2    Concert of machines and AGVs are assessed by u...
# 3    Introduction: Action potentials usually travel...
# 4    Currently, hydrogen fuel cell electric vehicle...
# ..                                                 ...
# 144  The order picking problem is an important issu...
# 146  In many person-on-board AS/R systems, some ver...
# 147  A methodology is presented based on linear pro...
# 148  Existing travel-time models of automated stora...
# 149  Multi-aisle S/R machine system (MASS) can subs...
#
#                                           authkeywords citedby_count  \
# 0    Automated Storage and Retrieval System | Energ...             0
# 1    AS/RS | Class-based storage | Regression analy...             1
# 2    Artificial Intelligence | AS/Rs | Machine Sche...             0
# 3    action potential | backpropagating action pote...             0
# 4    deep reinforcement learning | Hydrogen fuel ce...             1
# ..                                                 ...           ...
# 144  Automated warehousing systems | Order picking ...             3
# 146  Automated warehousing | order picking | rack l...            30
# 147                                               None            77
# 148                                               None           101
# 149                                               None            50
#
#     openaccess         freetoread freetoreadLabel fund_acr    fund_no  \
# 0            0               None            None     None  undefined
# 1            0               None            None     None  undefined
# 2            0               None            None     None  undefined
# 3            1      repositoryvor           Green     None  undefined
# 4            1  publisherfullgold            Gold      SZU     000661
# ..         ...                ...             ...      ...        ...
# 144          0               None            None     None  undefined
# 146          0               None            None     None  undefined
# 147          0               None            None     None  undefined
# 148          0               None            None     None  undefined
# 149          0               None            None     None  undefined
#
#             fund_sponsor
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4    Shenzhen University
# ..                   ...
# 144                 None
# 146                 None
# 147                 None
# 148                 None
# 149                 None
#
# [130 rows x 36 columns]

# %%
# plot records over time

bibvis.plot_records_over_time()

# %%
# plot country map

bibvis.plot_world_map_country_count()

# %%
bibvis.plot_keyword_worldcloud()
